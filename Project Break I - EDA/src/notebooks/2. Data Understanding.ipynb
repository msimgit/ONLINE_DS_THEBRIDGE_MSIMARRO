# %% [markdown]
# ### 2. Data Understanding

# %%
# Importamos las librerías necesarias
import pandas as pd

# %%
# Cargamos y guardamos cada tabla en un DataFrame independiente

paths = {
    'df_exped': '../data/source/exped.csv',
    'df_data': '../data/source/himalayan_data_dictionary.csv',
    'df_members': '../data/source/members.csv',
    'df_peaks': '../data/source/peaks.csv',
    'df_refer': '../data/source/refer.csv'
}

for name, path in paths.items():
    try:
        df = pd.read_csv(path, encoding='utf-8', low_memory=False)
    except UnicodeDecodeError:
        df = pd.read_csv(path, encoding='latin1', low_memory=False)
    globals()[name] = df

# %% [markdown]
# 8. **Exploratorio inicial**: en este momento realizaremos un primer análisis de las variables que tenemos en el dataset, obteniendo la información básica: cantidad de tablas, número de columnas, de filas, naturaleza de las variables, tipos de los datos, primeros registros y proporción de missings.

# %%
# Exploración de df_exped
df_exped.info()
df_exped.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11425 entries, 0 to 11424
# Data columns (total 65 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   expid       11425 non-null  object
#  1   peakid      11425 non-null  object
#  2   year        11425 non-null  int64
#  3   season      11425 non-null  object
#  4   host        11425 non-null  object
#  5   route1      11275 non-null  object
#  6   route2      360 non-null    object
#  7   route3      30 non-null     object
#  8   route4      5 non-null      object
#  9   nation      11425 non-null  object
#  10  leaders     11401 non-null  object
#  11  sponsor     10609 non-null  object
#  12  success1    11425 non-null  bool
#  13  success2    11425 non-null  bool
#  14  success3    11425 non-null  bool
#  15  success4    11425 non-null  bool
#  16  ascent1     2778 non-null   object
#  17  ascent2     101 non-null    object
#  18  ascent3     11 non-null     object
# ...

# %%
# Exploración de df_members
df_members.info()
df_members.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89000 entries, 0 to 88999
# Data columns (total 61 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   expid       89000 non-null  object
#  1   membid      89000 non-null  int64
#  2   peakid      89000 non-null  object
#  3   myear       89000 non-null  int64
#  4   mseason     89000 non-null  object
#  5   fname       88897 non-null  object
#  6   lname       87876 non-null  object
#  7   sex         89000 non-null  object
#  8   yob         83592 non-null  float64
#  9   citizen     88993 non-null  object
#  10  status      89000 non-null  object
#  11  residence   80170 non-null  object
#  12  occupation  58261 non-null  object
#  13  leader      89000 non-null  bool
#  14  deputy      89000 non-null  bool
#  15  bconly      89000 non-null  bool
#  16  nottobc     89000 non-null  bool
#  17  support     89000 non-null  bool
#  18  disabled    89000 non-null  bool
# ...

# %%
# Exploración de df_peaks
df_peaks.info()
df_peaks.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   peakid      480 non-null    object
#  1   pkname      480 non-null    object
#  2   pkname2     257 non-null    object
#  3   location    479 non-null    object
#  4   heightm     480 non-null    int64
#  5   heightf     480 non-null    int64
#  6   himal       480 non-null    object
#  7   region      480 non-null    object
#  8   open        480 non-null    bool
#  9   unlisted    480 non-null    bool
#  10  trekking    480 non-null    bool
#  11  trekyear    29 non-null     float64
#  12  restrict    275 non-null    object
#  13  phost       480 non-null    object
#  14  pstatus     480 non-null    object
#  15  pyear       362 non-null    float64
#  16  pseason     363 non-null    object
#  17  pmonth      357 non-null    object
#  18  pday        340 non-null    float64
# ...

# %% [markdown]
# 9. **Tabla de variables**: no está de más tener inventariadas todas las variables que vayas a usar, la naturaleza de las mismas, el tipo de dato y lo que piensas que va a aportar al análisis. Esto puede ser una hoja de cálculo perfectamente.

# %% [markdown]
# **Comentarios del alumno**
# Hacemos una primera exploración y nos permitimos en 'Notas' segmentar nuevamente los datos para poder encontrar relaciones entre las distintas tablas

# %% [markdown]
# *df_exped*
#
# | Columna/variable | Descripción | Tipo de Variable | Importancia inicial | Notas |
# |---|---|---|---|---|
# | accidents | Descripción de accidentes |---|---| Riesgos e Incidentes |
# | achievment | Logros destacados |---|---| Resultados y logros |
# | agency | Agencia comercial |---|---| Actvidad y Logística |
# | approach | Ruta de aproximación al pico |---|---| Actvidad y Logística |
# | ascent1 | Número de ascensos en la primera ruta |---|---| Actvidad y Logística |
# | ascent2 | Número de ascensos en la segunda ruta |---|---| Actvidad y Logística |
# | ascent3 | Número de ascensos en la tercera ruta |---|---| Actvidad y Logística |
# | ascent4 | Número de ascensos en la cuarta ruta |---|---| Actvidad y Logística |
# | bcdate | Fecha de llegada al campamento base |---|---| Actvidad y Logística |
# | camps | Número de campamentos |---|---| Actvidad y Logística |
# | campsites | Ubicación de campamentos |---|---| Actvidad y Logística |
# | chksum | Suma de verificación |---|---| --- |
# | claimed | ¿Se reclamó el ascenso sin evidencia? |---|---| Resultados y logros |
# | comrte | ¿Ruta comercial? |---|---| Actvidad y Logística |
# | countries | Otros países representados por los miembros |---|---| Actividad y Logística |
# | disputed | ¿Fue disputado o no verificado? |---|---| Resultados y logros |
# | expid | Identificador único de la expedición |---|---| Infromación general |
# | hdeaths | Muertes de contratados |---|---| Riesgos e Incidentes |
# | highpoint | Altura máxima alcanzada |---|---| Resultados y logros |
# | host | País desde el cual comenzó el ascenso |---|---| Información general |
# | leaders | Líderes de la expedición |---|---| Actividad y Logística |
# | mdeaths | Muertes de miembros |---|---| Actvidad y Logística, Riesgos e Incidentes |
# | nation | Nacionalidad principal de la expedición |---|---| Información general |
# | nohired | No se contrató personal |---|---| Actividad y Logística |
# | o2climb | ¿Se usó oxígeno durante el ascenso? |---|---| Resultados y logros, Actvidad y Logística |
# | o2descent | ¿Durante el descenso? |---|---| Resultados y logros |
# | o2medical | ¿Por razones médicas? |---|---| Resultados y logros |
# | o2none | ¿No se usó oxígeno? |---|---| Resultados y logros |
# | o2sleep | ¿Durante el sueño? |---|---| Resultados y logros |
# | o2taken | ¿Se llevó oxígeno pero no se usó? |---|---| Resultados y logros, Actividad y Logística |
# | o2unkwn | ¿Se desconoce si se usó? |---|---| Resultados y logros |
# | o2used | ¿Se usó oxígeno? |---|---| Resultados y logros, Actvidad y Logística |
# | othersmts | Otros picos alcanzados |---|---| Resultados y logros |
# | parapente | Descenso en parapente |---|---| Actividad y Logística |
# | peakid | Identificador del pico (relacionado con peak_name) |---|---| Información general, Actividad y Logística |
# | primid | ID principal de la expedición |---|---| Información general |
# | primmem | ¿Miembro principal? |---|---| Actividad y Logística |
# | primref | ¿Referencia principal? |---|---| Actividad y Logística |
# | primrte | ¿Ruta principal? |---|---| Actividad y Logística |
# | rope | Longitud de cuerda fija usada |---|---| Actividad y Logística |
# | route1 | Nombre de la primera ruta utilizada |---|---| Actividad y Logística |
# | route2 | Nombre de la segunda ruta utilizada |---|---| Actividad y Logística |
# | route3 | Nombre de la tercera ruta utilizada |---|---| Actividad y Logística |
# | route4 | Nombre de la cuarta ruta utilizada |---|---| Actividad y Logística |
# | season | Temporada (por ejemplo, primavera, otoño) |---|---| Actividad y Logística, Información general |
# | ski | Descenso esquiando |---|---| Actividad y Logística |
# | smtdays | Día de cumbre relativo al inicio |---|---| Actividad y Logística |
# | smtdate | Fecha de cumbre |---|---| Actividad y Logística |
# | smthired | Contratados que llegaron a la cumbre |---|---| Actividad y Logística |
# | smtmembers | Miembros que llegaron a la cumbre |---|---| Actividad y Logística |
# | smttime | Hora de cumbre |---|---| Actividad y Logística |
# | sponsor | Patrocinador |---|---| Actividad y Logística |
# | stdrte | ¿Ruta estándar? |---|---| Actividad y Logística |
# | success1 | Indicador de éxito en la primera ruta |---|---| Actividad y Logística |
# | success2 | Indicador de éxito en la segunda ruta |---|---| Actividad y Logística |
# | success3 | Indicador de éxito en la tercera ruta |---|---| Actividad y Logística |
# | success4 | Indicador de éxito en la cuarta ruta |---|---| Actividad y Logística |
# | termdate | Fecha de salida del campamento base o fin de expedición |---|---| Actividad y Logística |
# | termnote | Detalles adicionales sobre la finalización |---|---| Actividad y Logística |
# | termreason | Resultado o motivo de finalización |---|---| Actividad y Logística |
# | totdays | Días totales de la expedición |---|---| Actividad y Logística, Información general |
# | totmembers | Total de miembros |---|---| Actividad y Logística |
# | tothired | Personas contratadas |---|---| Actividad y Logística |
# | traverse | Travesía |---|---| Actividad y Logística |
# | year | Año de la expedición |---|---| Información general |

# %% [markdown]
# *df_members*
#
# | Columna/variable | Descripción | Tipo de Variable | Importancia inicial | Notas |
# |------------------|-------------|------------------|----------------------|-------|
# | bconly           | Sólo acamparon en el campamento base | --- | --- | Actividad y Logística |
# | citizen          | Ciudadanía del miembro | --- | --- | INformación general |
# | death            | Fallecido | --- | --- | Riesgos e Incidentes |
# | deathclass       | Clasificación del fallecimiento | --- | --- | Riesgos e Incidentes |
# | deathdate        | Fecha del fallecimiento | --- | --- | Riesgos e Incidentes |
# | deathhgtm        | Altura a la que falleció | --- | --- | Riesgos e Incidentes |
# | deathtime        | Hora del fallecimiento | --- | --- | Riesgos e Incidentes |
# | deathtype        | Tipo de fallecimiento | --- | --- | Riesgos e Incidentes |
# | deputy           | Sustituto | --- | --- | Actividad y Logística |
# | disabled         | Discapacitado | --- | --- | Riesgos e Incidentes |
# | expid            | Identificador de la expedición | --- | --- | Información general |
# | fname            | Nombre | --- | --- | Información general |
# | hcn              | Número de identificación de la cumbre | --- | --- | Información general |
# | hired            | Contratado | --- | --- | Riesgos e Incidentes |
# | leader           | Líder de la expedición | --- | --- | Actividad y Logística |
# | lname            | Apellido | --- | --- | Información general |
# | mascent1–3       | Ascensos realizados | --- | --- | Resultados y logros |
# | mclaimed         | Ascensión reclamada | --- | --- | Resultados y logros |
# | mdisputed        | Ascensión cuestionada | --- | --- | Información general |
# | membid           | Identificador único del miembro | --- | --- | Información general |
# | mhighpt          | Punto más alto alcanzado | --- | --- | Resultados y logros, Actividad y Logística |
# | mo2climb–mo2note | Uso de oxígeno y notas | --- | --- | Resultados y logros |
# | mparapente       | Descenso en parapente | --- | --- | Actividad y Logística |
# | mperhighpt       | Porcentaje del punto más alto alcanzado | --- | --- | Resultados y logros |
# | mroute1–3        | Rutas utilizadas | --- | --- | Actividad y Logística |
# | mseason          | Temporada de la expedición | --- | --- | Actividad y Logística |
# | mski             | Descenso esquiando | --- | --- | Resultados y logros |
# | msmtbid          | Identificador de cumbre | --- | --- | Información general |
# | msmtdate1–3      | Fechas de cumbre | --- | --- | Actividad y Logística |
# | msmtterm         | Resumen expedición | --- | --- | Resultados y logros |
# | msmttime1–3      | Horas de cumbre | --- | --- | Actividad y Logística |
# | msolo            | Ascenso en solitario | --- | --- | Resultados y logros |
# | mspeed           | Velocidad de ascenso | --- | --- | Resultados y logros |
# | msuccess         | Ascensión exitosa | --- | --- | Resultados y logros |
# | mtraverse        | Travesía realizada | --- | --- | Actividad y Logística |
# | myear            | Año de la expedición | --- | --- | Información general |
# | nottobc          | No llegó al campamento base | --- | --- | Resultados y logros |
# | occupation       | Profesión | --- | --- | Información general  |
# | peakid           | Identificador del pico | --- | --- | IInformación general |
# | residence        | Residencia | --- | --- | Información general |
# | sex              | Sexo | --- | --- | Información general |
# | sherpa           | ¿Es sherpa? | --- | --- | Información general, Actividad y Logística |
# | status           | Estado civil | --- | --- | Información general |
# | support          | ¿Es miembro de apoyo? | --- | --- | Información general |
# | tibetan          | ¿Es tibetano? | --- | --- | Información general, Actividad y Logística |
# | yob              | Año de nacimiento | --- | --- | Información general |

# %% [markdown]
# *df_peaks*
#
# | Columna/variable | Descripción | Tipo de Variable | Importancia inicial | Notas |
# |------------------|-------------|------------------|----------------------|-------|
# | heightf          | Altura del pico en pies | --- | --- | Información general |
# | heightm          | Altura del pico en metros | --- | --- | Información general |
# | himal            | Indica si el pico pertenece al Himalaya | --- | --- | Información general |
# | location         | Ubicación geográfica del pico | --- | --- | Información general |
# | phost            | País anfitrión del pico | --- | --- | Información general, Actividad y Logística |
# | region           | Región geográfica donde se encuentra el pico | --- | --- | Información general, Actividad y Logística |
# | pkname           | Nombre principal del pico | --- | --- | Información general |
# | pkname2          | Nombre alternativo del pico | --- | --- | Información general |
# | peakid           | Identificador único del pico | --- | --- | Información general |
# | pexpid           | Identificador de la expedición del primer ascenso | --- | --- | Información general |
# | pyear            | Año del primer ascenso registrado | --- | --- | Información general |
# | pseason          | Temporada del primer ascenso registrado | --- | --- | Información general |
# | pmonth           | Mes del primer ascenso registrado | --- | --- | Información general |
# | pday             | Día del primer ascenso registrado | --- | --- | Información general |
# | trekyear         | Año en que se permitió el trekking | --- | --- | Información general |
# | psummiters       | Nombre(s) de los primeros en alcanzar la cumbre | --- | --- | Resultados y Logros, Información general |
# | psmtnote         | Notas adicionales sobre el primer ascenso | --- | --- | Información general |
# | pcountry         | País de origen de la expedición de primer ascenso | --- | --- | Información general |
# | open             | Indica si el pico está abierto al público | --- | --- | Actividad y Logística |
# | pstatus          | Estado del pico (por ejemplo, abierto, cerrado) | --- | --- | Actividad y Logística, Información general |
# | restrict         | Restricciones de acceso al pico | --- | --- | Actividad y Logística, Información general |
# | trekking         | Indica si el pico es accesible mediante trekking | --- | --- | Actividad y Logística |
# | unlisted         | Indica si el pico no está listado oficialmente | --- | --- | Información general |
